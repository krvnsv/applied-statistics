# %% [markdown]
# # Applied Probability and Statistics Final Exam

# %% [markdown]
# ##  Dataset: Cryptocurrency historical prices
# ___

# %% [markdown]
# ## 0. Preparation
#
# - Importing the libraries and the dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy


# Importing data:
df=pd.read_csv('Crypto_historical_data.csv')
df
# Out:
#                              Date      Open      High       Low     Close  \
# 0       2017-11-09 00:00:00+00:00  0.002304  0.002438  0.002285  0.002344
# 1       2017-11-10 00:00:00+00:00  0.002335  0.002350  0.001989  0.002013
# 2       2017-11-11 00:00:00+00:00  0.002026  0.002298  0.001890  0.002003
# 3       2017-11-12 00:00:00+00:00  0.002006  0.002006  0.001684  0.001783
# 4       2017-11-13 00:00:00+00:00  0.001795  0.002146  0.001771  0.002112
# ...                           ...       ...       ...       ...       ...
# 348932  2025-11-15 00:00:00+00:00  0.000013  0.000014  0.000013  0.000013
# 348933  2025-11-16 00:00:00+00:00  0.000013  0.000013  0.000013  0.000013
# 348934  2025-11-17 00:00:00+00:00  0.000013  0.000013  0.000012  0.000012
# 348935  2025-11-18 00:00:00+00:00  0.000012  0.000013  0.000012  0.000013
# 348936  2025-11-19 00:00:00+00:00  0.000013  0.000013  0.000012  0.000012
#
#          Volume   ticker   name
# 0       2924350  TRX-USD   TRON
# ...

# %% [markdown]
# - Transforming data fields into a more desirable format

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.date
df
# Out:
#               Date      Open      High       Low     Close   Volume   ticker  \
# 0       2017-11-09  0.002304  0.002438  0.002285  0.002344  2924350  TRX-USD
# 1       2017-11-10  0.002335  0.002350  0.001989  0.002013  2193620  TRX-USD
# 2       2017-11-11  0.002026  0.002298  0.001890  0.002003  1748460  TRX-USD
# 3       2017-11-12  0.002006  0.002006  0.001684  0.001783  2174370  TRX-USD
# 4       2017-11-13  0.001795  0.002146  0.001771  0.002112  2889150  TRX-USD
# ...            ...       ...       ...       ...       ...      ...      ...
# 348932  2025-11-15  0.000013  0.000014  0.000013  0.000013  9183119  XEC-USD
# 348933  2025-11-16  0.000013  0.000013  0.000013  0.000013  8596172  XEC-USD
# 348934  2025-11-17  0.000013  0.000013  0.000012  0.000012  9196514  XEC-USD
# 348935  2025-11-18  0.000012  0.000013  0.000012  0.000013  6922388  XEC-USD
# 348936  2025-11-19  0.000013  0.000013  0.000012  0.000012  5924679  XEC-USD
#
#          name
# 0        TRON
# ...

# %% [markdown]
# - Selecting the desired ticker, default - 'BTC-USD'

# %%
ticker = 'BTC-USD' #change to see different data

df = df[df['ticker'] == ticker]
df = df[['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'ticker', 'name']]
df
# Out:
#              Date          Open          High           Low         Close  \
# 18508  2014-09-17    465.864014    468.174011    452.421997    457.334015
# 18509  2014-09-18    456.859985    456.859985    413.104004    424.440002
# 18510  2014-09-19    424.102997    427.834991    384.532013    394.795990
# 18511  2014-09-20    394.673004    423.295990    389.882996    408.903992
# 18512  2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...           ...           ...           ...           ...           ...
# 22585  2025-11-15  94420.468750  96728.468750  94420.468750  95549.148438
# 22586  2025-11-16  95556.867188  96564.187500  92971.164062  94177.078125
# 22587  2025-11-17  94180.875000  95928.367188  91214.757812  92093.875000
# 22588  2025-11-18  92094.531250  93745.078125  89300.460938  92948.875000
# 22589  2025-11-19  92944.140625  92944.140625  90013.195312  91187.421875
#
#              Volume   ticker     name
# 18508      21056800  BTC-USD  Bitcoin
# ...

# %% [markdown]
# - Adding 'Log' fields for a more accurate statistical analysis

# %%
# 3. Sort by Date to ensure calculations follow the correct time order
df = df.sort_values('Date')
# 4. Calculate Daily Log Returns (The "Shift" trick)
# Formula: ln(Today's Price / Yesterday's Price)
df['Log_Returns'] = np.log(df['Close'] / df['Close'].shift(1))

# Percentage returns
df['Pct_Returns'] = df['Close'].pct_change()
#df['Pct_Returns'] = np.exp(df['Log_Returns']) - 1 # formula from log

# Real dollar returns
df['Dollar_Returns'] = df['Close'].diff()

# 5. Calculate Log Volume (For your Regression later)
# We add 1 to avoid errors if volume is ever 0 (ln(0) is undefined)
df['Log_Volume'] = np.log(df['Volume'].replace(0, 1))

# 6. Cleanup: The first row will now have NaN (empty) values because 
# there is no "yesterday" for the first day. We drop it. For regression purposes mostly
returns = df.dropna()

returns
# Out:
#              Date          Open          High           Low         Close  \
# 18509  2014-09-18    456.859985    456.859985    413.104004    424.440002
# 18510  2014-09-19    424.102997    427.834991    384.532013    394.795990
# 18511  2014-09-20    394.673004    423.295990    389.882996    408.903992
# 18512  2014-09-21    408.084991    412.425995    393.181000    398.821014
# 18513  2014-09-22    399.100006    406.915985    397.130005    402.152008
# ...           ...           ...           ...           ...           ...
# 22585  2025-11-15  94420.468750  96728.468750  94420.468750  95549.148438
# 22586  2025-11-16  95556.867188  96564.187500  92971.164062  94177.078125
# 22587  2025-11-17  94180.875000  95928.367188  91214.757812  92093.875000
# 22588  2025-11-18  92094.531250  93745.078125  89300.460938  92948.875000
# 22589  2025-11-19  92944.140625  92944.140625  90013.195312  91187.421875
#
#              Volume   ticker     name  Log_Returns  Pct_Returns  \
# ...

# %% [markdown]
# ## 1. Unconditional and conditional probabilities
#
# - Unconditional probability of whether or not on a chosen day a token will go UP

# %%
up = (df['Log_Returns'] > 0).mean() * 100
down = (df['Log_Returns'] <= 0).mean() * 100

print(f"Unconditional probability UP:   {up:.2f}%")
print(f"Unconditional probability DOWN: {down:.2f}%")
# Out:
# Unconditional probability UP:   52.65%
# Unconditional probability DOWN: 47.33%

# %% [markdown]
# - Conditional probability of UP or DOWN being followed by UP
#
# $$
# P(A \mid B) = \frac{P(A \cap B)}{P(B)}
# $$

# %%
up_after_up = (
    ((df['Log_Returns'] > 0) & (df['Log_Returns'].shift(1) > 0)).sum()
    / (df['Log_Returns'].shift(1) > 0).sum() # .sum() bcs Pandas returns a Boolean Series
) * 100

up_after_down = (
    ((df['Log_Returns'] > 0) & (df['Log_Returns'].shift(1) <= 0)).sum()
    / (df['Log_Returns'].shift(1) <= 0).sum()
) * 100

print(f"P(UP today | UP yesterday):   {up_after_up:.2f}%")
print(f"P(UP today | DOWN yesterday): {up_after_down:.2f}%")
# Out:
# P(UP today | UP yesterday):   50.35%
# P(UP today | DOWN yesterday): 55.26%

# %% [markdown]
# ## 2. Estimation of the parameters

# %% [markdown]
# - Mathematical Expectation

# %%
# Load data and extract Log/Pct/Dollar returns
returns = df['Log_Returns']
abs_returns = np.abs(returns)

n = len(returns)
expected_value = np.sum(returns) / n

print(f"Formula: E(X) = (1/n) * Σ(x_i)")
print(f"n = {n}")
print(f"E(X) = {expected_value:.8f}")

# Graph 1
plt.figure(figsize=(10, 5))
plt.hist(returns, bins=50, alpha=0.7, color='steelblue', edgecolor='black')
plt.axvline(expected_value, color='red', linestyle='--', linewidth=2.5, label=f'Mean = {expected_value:.6f}')
plt.xlabel('Log Returns')
plt.ylabel('Frequency')
plt.title('Distribution of Log Returns')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Formula: E(X) = (1/n) * Σ(x_i)
# n = 4082
# E(X) = 0.00129722

# %% [markdown]
# - Standard deviation and Variance

# %%
deviations = returns - expected_value
squared_deviations = deviations ** 2
variance = np.sum(squared_deviations) / n
std_dev = np.sqrt(variance)

print(f"Formula: σ = √[(1/n) * Σ(x_i - E(X))²]")
print(f"Variance = {variance:.8f}")
print(f"σ = {std_dev:.8f}")
# Out:
# Formula: σ = √[(1/n) * Σ(x_i - E(X))²]
# Variance = 0.00126213
# σ = 0.03552652

# %% [markdown]
# - Median

# %%
sorted_returns = np.sort(returns)
if n % 2 == 0:
    median = (sorted_returns[n//2 - 1] + sorted_returns[n//2]) / 2
else:
    median = sorted_returns[n//2]

print(f"Formula (Median): Middle value of sorted data")
print(f"Median = {median:.8f}")
# Out:
# Formula (Median): Middle value of sorted data
# Median = 0.00123584

# %% [markdown]
# - Mode

# %%
returns_clean = returns.dropna()
hist, bin_edges = np.histogram(returns_clean, bins=50)
mode_bin = np.argmax(hist)
mode = (bin_edges[mode_bin] + bin_edges[mode_bin + 1]) / 2
print("Mode: Most frequent value")
print(f"Mode ≈ {mode:.8f}")
# Out:
# Mode: Most frequent value
# Mode ≈ -0.00253126

# %%
# Graph 2
plt.figure(figsize=(12, 6))
plt.hist(returns, bins=50, alpha=0.7, color='steelblue', edgecolor='black')
plt.axvline(expected_value, color='red', linestyle='-', linewidth=2.5, label=f'Mean = {expected_value:.6f}')
plt.axvline(median, color='green', linestyle='-', linewidth=2.5, label=f'Median = {median:.6f}')
plt.axvline(mode, color='purple', linestyle='-', linewidth=2.5, label=f'Mode ≈ {mode:.6f}')
plt.axvline(expected_value + std_dev, color='orange', linestyle='--', linewidth=2, label='+1σ')
plt.axvline(expected_value - std_dev, color='orange', linestyle='--', linewidth=2, label='-1σ')
plt.xlabel('Log Returns')
plt.ylabel('Frequency')
plt.title('Distribution with Mean, Median, Mode, and Standard Deviation Bands')
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
